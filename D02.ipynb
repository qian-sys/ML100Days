# %%
a = np.arange(15).reshape(3, 5)

print(a)
# Out:
#   File "<ipython-input-21-e9d07d88ddb1>", line 3
#     a = np.arange(15).reshape(3, 5)
#     ^
# IndentationError: unexpected indent

# %%
def is_dtype(a, t):
  a = np.arange(15).reshape(3, 5) 
print(is_dtype(a, 'int'))
# Out:
# None

# %%
1.
'\n type(...)傳回資料的結構類型(ex;list)，而a.dtype是傳回資料類型(ex;int) \n'
2.
a = np.arange(15).reshape(3, 5)
def is_dtype(a, t):
  return a.dtype==t
print(is_dtype(a, 'int')) 
print(is_dtype(a, np.int))
print(is_dtype(a, np.dtype('int')))
3.#應改成
def is_dtype(a, t):
    return a.dtype == t

def is_dtype(a, t):
    return a.dtype == np.dtype(t)

def is_dtype(a, t):
    return a.dtype is np.dtype(t)
# Out:
# True
# True
# True
